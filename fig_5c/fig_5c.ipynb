# %%
# The figures in the paper use processed data (data folder) that was checked and output using the 10x Genomics's Loupe browser. 
# Here we reproduce the data processing process there.

# 5c, UMAP clustering of 61,787 single-cell transcriptomes colored by main clusters in the whole epidermis.

# %%
import scanpy as sc
import os
import sys
sys.path.append(os.pardir)

model_name = 'normal'
results_analysis_file = '../data/calculated/preprocessing/{}_analysis.h5ad'.format(model_name)
seed = 0

# # if you need
import warnings
warnings.filterwarnings('ignore')

# %%
# based on base.ipyenb
adata_analysis = sc.read(results_analysis_file)

# %%
sc.pl.umap(adata_analysis, color=['louvain'], components = ['1,2'], ncols=1, size=2)

# IFE-1 : 1, 2, 3, 4, 6 
# IFE-2 : 14
# IFE-3 : 5, 7
# IFE-4 : 12, 13
# IFE Differentiated : 10
# Bulge : 8
# Isthmus : 16
# Sebaceous gland : 17
# Upper HF : 9, 15
# Melanocytes : 18
# T cells : 11
# Langerhans cells : 19
